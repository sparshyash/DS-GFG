# %% [markdown]
# Binomial Distribution calculates the probability of getting exactly
# xsuccesses in
# nindependent trials. The formula for the Probability Mass Function (PMF) is:
#
# P(X=x)=( nCx )  p^x  (1−p)^ n−x
#
# P(X=x) is the probability of getting exactly x successes.
#
# n   is the number of trials.
# x is the number of successes we want to calculate the probability for.
# p is the probability of success in each trial.
# ( nCx )   is the binomial coefficient which represents the number of ways to arrange  x successes in n  trials. It is calculated as:
# ( nCx)= n!  / x! *(n-x)!
#
#
# ​

# %% [markdown]
# Expected Value of the Binomial Distribution
# The expected value (mean) of a Binomial Distribution represents the average number of successes we expect after performing n trials. The expected value is calculated as:

# %% [markdown]
# . Variance: The variance of a Binomial Distribution measures how much the number of successes varies from the expected value. It is given by:
